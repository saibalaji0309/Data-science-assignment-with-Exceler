# %%
import pandas as pd
df=pd.read_csv('wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
# checking any null values 
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
# checking any duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Type, Alcohol, Malic, Ash, Alcalinity, Magnesium, Phenols, Flavanoids, Nonflavanoids, Proanthocyanins, Color, Hue, Dilution, Proline]
# Index: []

# %%
df.dtypes
# Out:
# Type                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
df.shape
# Out:
# (178, 14)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogrtam
df.hist(figsize=(12,8))
plt.show()


# box-plot

fig,ax=plt.subplots(figsize=(20,20))
sns.boxplot(data=df,ax=ax)
# Out:
# <Axes: >

# %%
#  Density for every feature
import seaborn as sns
for n in df.columns:
    print(n)
    sns.kdeplot(df[n])
    plt.show()
# Out:
# Type
# C:\Users\jalli\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Alcohol
# C:\Users\jalli\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Malic
# C:\Users\jalli\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Ash
# ...

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X=ss.fit_transform(df.iloc[:,1:])
Y=df['Type']

# %%
from sklearn.decomposition import PCA
import numpy as np
X_scaled = X

# Perform PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Scree Plot
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.show()

# Cumulative Explained Variance Plot
cumulative_explained_variance = np.cumsum(explained_variance_ratio)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.axhline(y=0.90, color='r', linestyle='-')
plt.title('Cumulative Explained Variance')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# Determine the number of components that explain at least 90% of the variance
num_components = np.argmax(cumulative_explained_variance >= 0.90) + 1
print(f'Number of principal components that explain at least 90% of the variance: {num_components}')
# Out:
# Number of principal components that explain at least 90% of the variance: 8

# %%
# Determine the number of components that explain at least 90% of the variance
num_components = np.argmax(cumulative_explained_variance >= 0.90) + 1
print(f'Number of principal components that explain at least 90% of the variance: {num_components}')

# Apply PCA with the optimal number of components
pca_optimal = PCA(n_components=num_components)
X_pca_optimal = pca_optimal.fit_transform(X)


# # Create a DataFrame with the principal components
columns = [f'PC{i+1}' for i in range(num_components)]
columns
df_pca = pd.DataFrame(X_pca_optimal, columns=columns)

# # Show the first few rows of the transformed dataset
print(df_pca.head())
# Out:
# Number of principal components that explain at least 90% of the variance: 8
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  3.316751 -1.443463 -0.165739 -0.215631  0.693043 -0.223880  0.596427
# 1  2.209465  0.333393 -2.026457 -0.291358 -0.257655 -0.927120  0.053776
# 2  2.516740 -1.031151  0.982819  0.724902 -0.251033  0.549276  0.424205
# 3  3.757066 -2.756372 -0.176192  0.567983 -0.311842  0.114431 -0.383337
# 4  1.008908 -0.869831  2.026688 -0.409766  0.298458 -0.406520  0.444074
#
#         PC8
# 0  0.065139
# 1  1.024416
# 2 -0.344216
# 3  0.643593
# 4  0.416700

# %% [markdown]
# # Task 3: Clustering with Original Data:

# %%
from sklearn.cluster import KMeans

# Compute silhouette score
from sklearn.metrics import silhouette_score

ss_score = []
for i in range(2,11,1):
    kmeans = KMeans(n_clusters=i,n_init=20)
    Y2 = kmeans.fit_predict(X)
    ss_score.append(silhouette_score(X, Y2))


import matplotlib.pyplot as plt
plt.scatter(range(2,11,1),ss_score)
plt.plot(range(2,11,1),ss_score,color='red')
plt.xlabel("k vlaues")
plt.ylabel("s scores")
plt.show()
# Out:
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [raw]
# # at k=3 we got the better results

# %% [markdown]
# # Task 4: Clustering with PCA Data:

# %%
from sklearn.cluster import KMeans

# Compute silhouette score
from sklearn.metrics import silhouette_score

ss_score = []
for i in range(2,11,1):
    kmeans = KMeans(n_clusters=i,n_init=20)
    Y2 = kmeans.fit_predict(df_pca)
    ss_score.append(silhouette_score(df_pca, Y2))


import matplotlib.pyplot as plt
plt.scatter(range(2,11,1),ss_score)
plt.plot(range(2,11,1),ss_score,color='red')
plt.xlabel("k vlaues")
plt.ylabel("s scores")
plt.show()
# Out:
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,n_init=5)
Y = kmeans.fit_predict(df_pca)
Y

Y = pd.DataFrame(Y)
print(Y.value_counts())

# Compute silhouette score
from sklearn.metrics import silhouette_score
silhouettescore = silhouette_score(df_pca, Y)
silhouettescore


Y_act = df['Type']
print(Y_act.value_counts())


from sklearn.metrics import confusion_matrix
confusion_matrix(Y_act,Y)
# Out:
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# 0    65
# 1    62
# 2    51
# Name: count, dtype: int64
# Type
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64
# C:\Users\jalli\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[ 0,  0,  0,  0],
#        [ 0, 59,  0,  0],
#        [65,  3,  3,  0],
#        [ 0,  0, 48,  0]], dtype=int64)

# %% [raw]
# While comparing the data with Pca and without PCA
# we came to know that Without using PCA method we are considering 12 X variable for determining the Target Variable
# while use PCA we just used 8 X Variables this saves the run-time and also there is no change in there Accuracy
